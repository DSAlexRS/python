# %% [markdown]
# <a href="https://colab.research.google.com/github/DSAlexRS/python/blob/master/MLzoomcamp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #question 1

# %%
#question 1
np.__version__
# Out:
# '1.21.6'

# %%
df = pd.read_csv("https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv")

# %%
df.head(2)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %% [markdown]
# #question 2

# %%
df.shape
# Out:
# (11914, 16)

# %%
df.Make.describe(include="o")
# Out:
# count         11914
# unique           48
# top       Chevrolet
# freq           1123
# Name: Make, dtype: object

# %%
df.Make.unique()
# Out:
# array(['BMW', 'Audi', 'FIAT', 'Mercedes-Benz', 'Chrysler', 'Nissan',
#        'Volvo', 'Mazda', 'Mitsubishi', 'Ferrari', 'Alfa Romeo', 'Toyota',
#        'McLaren', 'Maybach', 'Pontiac', 'Porsche', 'Saab', 'GMC',
#        'Hyundai', 'Plymouth', 'Honda', 'Oldsmobile', 'Suzuki', 'Ford',
#        'Cadillac', 'Kia', 'Bentley', 'Chevrolet', 'Dodge', 'Lamborghini',
#        'Lincoln', 'Subaru', 'Volkswagen', 'Spyker', 'Buick', 'Acura',
#        'Rolls-Royce', 'Maserati', 'Lexus', 'Aston Martin', 'Land Rover',
#        'Lotus', 'Infiniti', 'Scion', 'Genesis', 'HUMMER', 'Tesla',
#        'Bugatti'], dtype=object)

# %% [markdown]
# #Question 3

# %%
#question 3
df.groupby("Make").count().sort_values("Model", ascending=False)
# Out:
#                Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# Make
# Chevrolet       1123  1123              1123       1117              1121
# Ford             881   881               881        868               881
# Volkswagen       809   809               809        809               805
# Toyota           746   746               746        744               745
# Dodge            626   626               626        626               626
# Nissan           558   558               558        548               558
# GMC              515   515               515        515               515
# Honda            449   449               449        447               449
# Mazda            423   423               423        423               403
# Cadillac         397   397               397        397               397
# Mercedes-Benz    353   353               353        352               353
# Suzuki           351   351               348        351               351
# ...

# %% [markdown]
# #Question 4

# %%
len(df[df["Make"]=="Audi"].Model.unique())
# Out:
# 34

# %% [markdown]
# #Question 5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# #Question 6

# %%
df["Engine Cylinders"].median()
# Out:
# 6.0

# %%
df["Engine Cylinders"].mode()
# Out:
# 0    4.0
# dtype: float64

# %%
df["Engine Cylinders"].fillna(4).median()
# Out:
# 6.0

# %% [markdown]
# #Question 7

# %%
df1 = df[df["Make"]=="Lotus"]

# %%
df2 = df1[["Engine HP", "Engine Cylinders"]].drop_duplicates()

# %%
x = np.array(df2)

# %%
x
# Out:
# array([[189.,   4.],
#        [218.,   4.],
#        [217.,   4.],
#        [350.,   8.],
#        [400.,   6.],
#        [276.,   6.],
#        [345.,   6.],
#        [257.,   4.],
#        [240.,   4.]])

# %%
tx =x.T

# %%
txt = tx.dot(x)

# %%
inv = np.linalg.inv(txt)

# %%
m = inv.dot(tx)

# %%
m.dot(y)
# Out:
# array([  4.59494481, -63.56432501])

# %%
y = [1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800]

# %%
y = np.array(y)
